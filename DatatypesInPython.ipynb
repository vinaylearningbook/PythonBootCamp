# %% [markdown]
# <a href="https://colab.research.google.com/github/vinaylearningbook/PythonBootCamp/blob/main/DatatypesInPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
DataTypes in Python

# %% [markdown]
# Data types in Python are
#
# Int
#
# Float
#
# string
#
# list
#
# dict
#
# tuple
#
# set
#
# Boolean

# %% [markdown]
# working with numbers in Python

# %%
a = 10

# %%
a = a+a
print(a)
# Out:
# 20

# %%
type(a)
# Out:
# int

# %%
a = 10.1

# %%
type(a)
# Out:
# float

# %%
a = "hello"

# %%
print(a[0])
# Out:
# h

# %%
print(a[0:4:2]) # slicing of a string in Python
# Out:
# hl

# %%
len(a)
# Out:
# 5

# %%
#reverse indexing
a[-1]
# Out:
# 'o'

# %%
a[-2]
# Out:
# 'l'

# %%
a[0:-3:1]
# Out:
# 'he'

# %%
#reverse the string
a[::-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_517/627804680.py in <cell line: 0>()
#       1 #reverse the string
# ----> 2 a[::-1]
#
# NameError: name 'a' is not defined

# %%
#Immutability

# %%
name = "Sam"

# %%
#strings are immutable meaning they cannot be changed index wise / item assignment
# name[0] ='P' - this is not possible insteam we should chnage the whole string or create a new one

# %%
name = "Pam"

# %%
name = "Sam"

# %%
last_letters = name[1:]

# %%
print(last_letters)
# Out:
# am

# %%
'P' + last_letters # string Concatenation
# Out:
# 'Pam'

# %%
#multiplication with strings or characters
letters = 'z'

# %%
letters * 10
# Out:
# 'zzzzzzzzzz'

# %%
x = "Hello World"

# %%
x.capitalize
# Out:
# <function str.capitalize()>

# %%
x.capitalize()
# Out:
# 'Hello world'

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x.lower()
# Out:
# 'hello world'

# %%
x.split()
# Out:
# ['Hello', 'World']

# %%
y = "Hi this is a string"

# %%
y.split() # split on spaces
# Out:
# ['Hi', 'this', 'is', 'a', 'string']

# %%
y.split('i') #split based on the provided character
# Out:
# ['H', ' th', 's ', 's a str', 'ng']
